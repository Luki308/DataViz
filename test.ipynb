# %%
from evaluate import ClusteringEvaluator
# %load_ext autoreload
# %autoreload 2

# %%
ce = ClusteringEvaluator()
display(ce.results_df)
ce.do_all("wut","x2", plot=True)
display(ce.results_df)
# Out:
# Empty DataFrame
# Columns: [battery, dataset, method, n_clusters, rand_score, silhouette_score, NCA]
# Index: []
# Loaded data for wut - x2
#    battery dataset         method  n_clusters  rand_score  silhouette_score  \
# 0      wut      x2         kmeans           3    0.209055          0.589260
# 1      wut      x2         kmeans           4    0.845752          0.478250
# 2      wut      x2         dbscan           3    0.281365          0.467713
# 3      wut      x2         dbscan           4    0.506334          0.467713
# 4      wut      x2  agglomerative           3    0.190597          0.584638
# 5      wut      x2  agglomerative           4    0.842505          0.470456
# 6      wut      x2  agglomerative           3   -0.006923          0.055818
# 7      wut      x2  agglomerative           4    0.046662          0.097442
# 8      wut      x2  agglomerative           3    0.209055          0.589260
# 9      wut      x2  agglomerative           4    0.868695          0.478547
# 10     wut      x2  agglomerative           3    0.250166          0.558457
# 11     wut      x2  agglomerative           4    0.444120          0.567144
# 12     wut      x2          genie           3    0.688287          0.442230
# 13     wut      x2          genie           4    0.686011          0.338252
# 14     wut      x2          genie           3    0.688287          0.442230
# 15     wut      x2          genie           4    0.686011          0.338252
# 16     wut      x2          genie           3    0.209055          0.589260
# 17     wut      x2          genie           4    0.439602          0.514737
# 18     wut      x2          genie           3    0.271308          0.560570
# 19     wut      x2          genie           4    0.467878          0.572312
# 20     wut      x2          genie           3   -0.014371          0.363781
# 21     wut      x2          genie           4    0.062633          0.378320
#
#          NCA   params   linkage  gini_threshold
# 0   0.260000  default       NaN             NaN
# 1   0.738636  default       NaN             NaN
# 2   0.230000  default       NaN             NaN
# 3   0.465909  default       NaN             NaN
# 4   0.250000  default      ward             NaN
# 5   0.738636  default      ward             NaN
# 6   0.010000  default    single             NaN
# 7   0.075000  default    single             NaN
# 8   0.260000  default  complete             NaN
# 9   0.750000  default  complete             NaN
# 10  0.330000  default   average             NaN
# 11  0.563636  default   average             NaN
# 12  0.870000  default       NaN             0.1
# 13  0.379032  default       NaN             0.1
# 14  0.870000  default       NaN             0.3
# 15  0.379032  default       NaN             0.3
# 16  0.260000  default       NaN             0.5
# 17  0.543182  default       NaN             0.5
# 18  0.340000  default       NaN             0.7
# 19  0.575000  default       NaN             0.7
# 20  0.030000  default       NaN             0.9
# 21  0.120455  default       NaN             0.9

# %%
# Out:
#    battery dataset         method  n_clusters  rand_score  silhouette_score  \
# 0      wut      x2         kmeans           3    0.597059          0.589260
# 1      wut      x2         kmeans           4    0.937535          0.478250
# 2      wut      x2         dbscan           3    0.645238          0.467712
# 3      wut      x2         dbscan           4    0.757983          0.467712
# 4      wut      x2  agglomerative           3    0.585574          0.584638
# 5      wut      x2  agglomerative           4    0.935994          0.470456
# 6      wut      x2  agglomerative           3    0.347759          0.055818
# 7      wut      x2  agglomerative           4    0.328992          0.097442
# 8      wut      x2  agglomerative           3    0.597059          0.589260
# 9      wut      x2  agglomerative           4    0.947059          0.478547
# 10     wut      x2  agglomerative           3    0.610224          0.558457
# 11     wut      x2  agglomerative           4    0.714286          0.567144
# 12     wut      x2          genie           3    0.859524          0.442230
# 13     wut      x2          genie           4    0.871989          0.338253
# 14     wut      x2          genie           3    0.859524          0.442230
# 15     wut      x2          genie           4    0.871989          0.338253
# 16     wut      x2          genie           3    0.597059          0.589260
# 17     wut      x2          genie           4    0.717507          0.514737
# 18     wut      x2          genie           3    0.622829          0.560570
# 19     wut      x2          genie           4    0.728711          0.572311
# 20     wut      x2          genie           3    0.358403          0.363781
# 21     wut      x2          genie           4    0.354622          0.378321
#
#          NCA   params   linkage  gini_threshold
# 0   0.260000  default       NaN             NaN
# 1   0.738636  default       NaN             NaN
# 2   0.230000  default       NaN             NaN
# 3   0.465909  default       NaN             NaN
# 4   0.250000  default      ward             NaN
# 5   0.738636  default      ward             NaN
# 6   0.010000  default    single             NaN
# 7   0.075000  default    single             NaN
# 8   0.260000  default  complete             NaN
# 9   0.750000  default  complete             NaN
# 10  0.330000  default   average             NaN
# 11  0.563636  default   average             NaN
# 12  0.870000  default       NaN             0.1
# 13  0.379032  default       NaN             0.1
# 14  0.870000  default       NaN             0.3
# 15  0.379032  default       NaN             0.3
# 16  0.260000  default       NaN             0.5
# 17  0.543182  default       NaN             0.5
# 18  0.340000  default       NaN             0.7
# 19  0.575000  default       NaN             0.7
# 20  0.030000  default       NaN             0.9
# 21  0.120455  default       NaN             0.9
